# %%
import matplotlib.pyplot as plt
import numpy as np

# Frequenze delle lettere
frequenze = {
    'a': 0.12377353175907234,
    'b': 0.016525045772498945,
    'c': 0.04314938265809117,
    'd': 0.048689028684099335,
    'e': 0.13180719215060327,
    'f': 0.004160602788601474,
    'g': 0.012229472794704474,
    'h': 0.0163842073142106,
    'i': 0.04827238157832966,
    'j': 0.005252100840336135,
    'k': 8.215576733486691E-5,
    'l': 0.05320172761842167,
    'm': 0.03140697619830055,
    'n': 0.06599455424627952,
    'o': 0.10111027651283977,
    'p': 0.03176494061311676,
    'q': 0.01394887563964133,
    'r': 0.0687761137974743,
    's': 0.06756725036383268,
    't': 0.039563870240833764,
    'u': 0.04548495375803953,
    'v': 0.010956058401014037,
    'w': 0.0,  
    'x': 6.807192150603258E-4,
    'y': 0.013761091028590206,
    'z': 0.005457490258673302
}

# Ordina le lettere per frequenza
letters = list(frequenze.keys())
frequencies = list(frequenze.values())

sorted_indices = np.argsort(frequencies)[::-1]  # Ordina in ordine decrescente
sorted_letters = [letters[i] for i in sorted_indices]
sorted_frequencies = [frequencies[i] for i in sorted_indices]

# Genera i colori scalando dal rosso al verde
cmap = plt.get_cmap('RdYlGn')
norm = plt.Normalize(min(sorted_frequencies), max(sorted_frequencies))
colors = cmap(norm(sorted_frequencies))

# Crea l'istogramma
plt.figure(figsize=(10, 6))
bars = plt.bar(sorted_letters, sorted_frequencies, color=colors)

# Aggiungi le etichette e il titolo
# Aggiungi le etichette e il titolo con un carattere più grande
plt.xlabel('Letters', fontsize=20)
plt.ylabel('Frequency', fontsize=20)
plt.title('Letter Frequencies in Spanish', fontsize=25)

# Aumenta il carattere dei valori sull'asse x
plt.xticks(rotation=45, fontsize=17)

# Per aumentare il carattere dei valori sull'asse y, usa il parametro fontsize in plt.yticks()
plt.yticks(fontsize=17)

# Aggiungi le righe orizzontali tratteggiate per le frequenze specificate
for y in np.arange(0.02, max(sorted_frequencies)+0.02 , 0.02):
    plt.axhline(y=y, color='gray', linestyle='--', linewidth=0.5)

# Mostra il grafico
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Frequenze delle lettere
frequenze = {
    'b': 4.617847467367211E-5,
    'e': 0.0747270339052623,
    'h': 0.02731713324029226,
    'k': 0.05397750595189229,
    'n': 0.09899125687546179,
    't': 0.09360889910516378,
    'c': 0.005264346112798621,
    'f': 1.282735407602003E-4,
    'i': 0.11318857236680076,
    'l': 0.056635333716443644,
    'o': 0.054331540924390444,
    'r': 0.017645308266973154,
    'u': 0.04847200558246449,
    'x': 5.541416960840654E-4,
    'a': 0.17447253920039404,
    'd': 0.00567995238486167,
    'g': 9.184385518430342E-4,
    'j': 0.018994745915770463,
    'm': 0.03023663902799442,
    'p': 0.021303669649454068,
    's': 0.06623019456530663,
    'v': 0.021688490271734667,
    'y': 0.015587800673179542
}

# Ordina le lettere per frequenza
letters = list(frequenze.keys())
frequencies = list(frequenze.values())

sorted_indices = np.argsort(frequencies)[::-1]  # Ordina in ordine decrescente
sorted_letters = [letters[i] for i in sorted_indices]
sorted_frequencies = [frequencies[i] for i in sorted_indices]

# Genera i colori scalando dal rosso al verde
cmap = plt.get_cmap('RdYlGn')
norm = plt.Normalize(min(sorted_frequencies), max(sorted_frequencies))
colors = cmap(norm(sorted_frequencies))

# Crea l'istogramma
plt.figure(figsize=(10, 6))
bars = plt.bar(sorted_letters, sorted_frequencies, color=colors)

# Aggiungi le etichette e il titolo
plt.xlabel('Letters')
plt.ylabel('Frequency')
plt.title('Letter Frequencies in Finnish')
plt.xticks(rotation=45)

# Mostra il grafico
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Frequenze delle lettere
frequenze = {
    'b': 4.617847467367211E-5,
    'e': 0.0747270339052623,
    'h': 0.02731713324029226,
    'k': 0.05397750595189229,
    'n': 0.09899125687546179,
    't': 0.09360889910516378,
    'c': 0.005264346112798621,
    'f': 1.282735407602003E-4,
    'i': 0.11318857236680076,
    'l': 0.056635333716443644,
    'o': 0.054331540924390444,
    'r': 0.017645308266973154,
    'u': 0.04847200558246449,
    'x': 5.541416960840654E-4,
    'a': 0.17447253920039404,
    'd': 0.00567995238486167,
    'g': 9.184385518430342E-4,
    'j': 0.018994745915770463,
    'm': 0.03023663902799442,
    'p': 0.021303669649454068,
    's': 0.06623019456530663,
    'v': 0.021688490271734667,
    'y': 0.015587800673179542
}

# Ordina le lettere per frequenza
letters = list(frequenze.keys())
frequencies = list(frequenze.values())

sorted_indices = np.argsort(frequencies)[::-1]  # Ordina in ordine decrescente
sorted_letters = [letters[i] for i in sorted_indices]
sorted_frequencies = [frequencies[i] for i in sorted_indices]

# Genera i colori scalando dal rosso al verde
cmap = plt.get_cmap('RdYlGn')
norm = plt.Normalize(min(sorted_frequencies), max(sorted_frequencies))
colors = cmap(norm(sorted_frequencies))

# Crea l'istogramma
plt.figure(figsize=(10, 6))
bars = plt.bar(sorted_letters, sorted_frequencies, color=colors)

# Aggiungi le etichette e il titolo
plt.xlabel('Letters')
plt.ylabel('Frequency')
plt.title('Letter Frequencies in Finnish')
plt.xticks(rotation=45)

# Mostra il grafico
plt.tight_layout()
plt.show()

# %%
# %pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3 -> 24.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
